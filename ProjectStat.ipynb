# %% [markdown]
# # Students
# ULB-student : INFO-F422 : Yasin ARSLAN : 000396506
#
# ULB-student : INFO-F422 : Zakariya HAMMOUCHI : 000412968
#
#
# # Requirements & Usage
#
# - Scikit-learn
# - Pandas
# - Matplotlib
# - Numpy
#
# We also provide some dataset files in csv :
# - People.csv
# - Network.csv

# %%
# !pip install scikit-learn==0.22
# !pip install -U nltk
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already up-to-date: nltk in /srv/conda/envs/notebook/lib/python3.6/site-packages (3.5)
# ...

# %%
import sklearn.metrics as metrics
import itertools 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC           # Support Vector Classifier
from matplotlib.colors import ListedColormap
# Confusion matrix for Poly kernel

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    See full source and example: 
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix \n")
    else:
        print('Confusion matrix, without normalization \n')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# # 1. Introduction
#
# This paper will present different ML-algorithms applied on different datasets. We will in this paper discuss analyze the results.
#
# ## 1.1 Datasets used
#
# We used Support Vector Machines classification algorithm on two datasets in separate runs to see the results. One of the dataset was found in kaggle.com available as Network.csv and the other one is created by our own, we called it People.csv.
# The Dataset fetched from a social media describes whether users have purchased a product by clicking on the advertisements shown to them. This is represented by the Column Purchased.
#
# A third dataset is added and used for regression algorithms. It is available as Salary.csv. The data represents the salary of employees in relation with their year of experience.
#
# ## 1.2 Result analysis
#
# We will mainly use the confusion matrix after computing it to measure the performences. The figure below shows an example of Confusion matrix where the output can be two or more classes. In our case it will be always 2 classes. It is a table with 4 different combinations that collapse the predicted value with the actual value.
#
# ![confusion.PNG](attachment:confusion.PNG)
#
# We can so compute the accuracy of the prediction by dividing the number of prediction by the sum of True-Positive and True-Negative.
# ##### Sum(all) / (TP+TN)

# %% [markdown]
# ### 1.1.1 Network.csv dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC           # Support Vector Classifier
from matplotlib.colors import ListedColormap

data = pd.read_csv('Network.csv')

# Distribution of ages & Salaries for Network
age = data.iloc[:, 2]
salary = data.iloc[:, 3]

print("Analytics of data")
print(data.describe())
print("Example of 5 entries from the dataset")
print("-----------------------------------------------")
print(data.head())
print("-----------------------------------------------")
print()
print("Age distribution in the dataset")
plt.hist(age)
plt.show()
print("Salaries distribution in the dataset")
plt.hist(salary)
plt.show()
# Out:
# Analytics of data
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000
# Example of 5 entries from the dataset
# -----------------------------------------------
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# ...

# %% [markdown]
# ### 1.1.2 People.csv dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC           # Support Vector Classifier
from matplotlib.colors import ListedColormap

data = pd.read_csv('People.csv')

# Distribution of ages & Salaries for Network
age = data.iloc[:, 2]
salary = data.iloc[:, 3]

print("Analytics of data")
print(data.describe())
print("Example of 5 entries from the dataset")
print("-----------------------------------------------")
print(data.head())
print("-----------------------------------------------")
print()
print("Age distribution in the dataset")
plt.hist(age)
plt.show()
print("Salaries distribution in the dataset")
plt.hist(salary)
plt.show()
# Out:
# Analytics of data
#                  id          Age        Salaire        Achat
# count  1.000000e+03  1000.000000    1000.000000  1000.000000
# mean   4.977517e+09    39.642000  111483.818000     0.477000
# std    2.874426e+09    12.082211   53298.427227     0.499721
# min    4.765360e+05    20.000000   15044.000000     0.000000
# 25%    2.348608e+09    29.000000   66030.500000     0.000000
# 50%    5.016515e+09    40.000000  113797.500000     0.000000
# 75%    7.420171e+09    51.000000  156755.000000     1.000000
# max    9.969995e+09    60.000000  199943.000000     1.000000
# Example of 5 entries from the dataset
# -----------------------------------------------
#            id Genre  Age  Salaire  Achat
# 0  2570438502     M   20    47036      1
# 1   438765540     F   30    99730      1
# 2  9784023776     F   38   197459      1
# 3  5278412380     F   33    50248      0
# 4  5776057280     M   33   146710      0
# -----------------------------------------------
#
# ...

# %% [markdown]
# ## 1.1.3 Salary dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC           # Support Vector Classifier
from matplotlib.colors import ListedColormap

data = pd.read_csv('Salary.csv')

# Distribution of ages & Salaries for Network
experience = data.iloc[:, 0]
salary = data.iloc[:, 1]

print("Analytics of data")
print(data.describe())
print("Example of 5 entries from the dataset")
print("-----------------------------------------------")
print(data.head())
print("-----------------------------------------------")
print()
print("Experience distribution in the dataset")
plt.hist(experience)
plt.show()
print("Salaries distribution in the dataset")
plt.hist(salary)
plt.show()
# Out:
# Analytics of data
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000
# Example of 5 entries from the dataset
# -----------------------------------------------
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# -----------------------------------------------
#
# Experience distribution in the dataset
# Salaries distribution in the dataset

# %% [markdown]
# # 2. Support Vector Machines
#
# SVM, also called Large Margin Classifier, is a supervised learning models meaning that it it maps an input to an output based on existing examples of input-outputs pairs. In this case, SVM will try to create two groups from your data using a hyperplane. The idea is to try to separate the data such as the margin between both classes are the most different as possible.
#
# ## 2.1 Network.csv dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

data = pd.read_csv('Network.csv')

# %% [markdown]
# ### Linear Kernel Classifier and Confusion matrix

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

# Training phase
x = data.iloc[:, 2:4]   # We get the Age and Salaire values
y = data.iloc[:, 4]     # We get the value that we want to find out: Achat
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.25)

# Scaling phase
xSca = StandardScaler()
xTrain = xSca.fit_transform(xTrain)
xTest = xSca.transform(xTest)

# Initializing the classifier using SVC
# note that we use linear kernel
clf = SVC(kernel='linear', random_state=0).fit(xTrain, yTrain)

# Plot with Linear Kernel
xSet, ySet = xTrain, yTrain
X1, X2 = np.meshgrid(np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01),
                     np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01))
plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))
for i, j in enumerate(np.unique(ySet)):
    plt.scatter(xSet[ySet == j, 0], xSet[ySet == j, 1],
                c=ListedColormap(('blue', 'green'))(i), label=j)
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
plt.title('SVC (Linear Kernel) Classifier')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
import sklearn.metrics as metrics
import itertools 
# Confusion matrix for linear kernel

y_pred = clf.predict(xTest)

score = metrics.accuracy_score(yTest, y_pred)
print("Accuracy: %0.3f" % score)
cm = metrics.confusion_matrix(yTest, y_pred, labels=[0, 1])
plot_confusion_matrix(cm, classes=['False', 'True'])
# Out:
# Accuracy: 0.870
# Confusion matrix, without normalization

# %% [markdown]
# ### Poly Kernel Classifier and Confusion matrix

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Same moves, using poly kernel
clf = SVC(kernel='poly', random_state=0).fit(xTrain, yTrain)

#Plot with Poly kernel
xSet, ySet = xTrain, yTrain
X1, X2 = np.meshgrid(np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01),
                     np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01))
plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))
for i, j in enumerate(np.unique(ySet)):
    plt.scatter(xSet[ySet == j, 0], xSet[ySet == j, 1],
                c=ListedColormap(('blue', 'green'))(i), label=j)

plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
plt.title('SVC (Polynomial Kernel) Classifier')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
y_pred = clf.predict(xTest)

score = metrics.accuracy_score(yTest, y_pred)
print("Accuracy: %0.3f" % score)
cm = metrics.confusion_matrix(yTest, y_pred, labels=[0, 1])
plot_confusion_matrix(cm, classes=['False', 'True'])
# Out:
# Accuracy: 0.870
# Confusion matrix, without normalization

# %% [markdown]
# ## 2.2 People.csv dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

data = pd.read_csv('People.csv')

print("Example of 5 entries from the dataset")
print("-----------------------------------------------")
print(data.head())
print("-----------------------------------------------")
# Out:
# Example of 5 entries from the dataset
# -----------------------------------------------
#            id Genre  Age  Salaire  Achat
# 0  2570438502     M   20    47036      1
# 1   438765540     F   30    99730      1
# 2  9784023776     F   38   197459      1
# 3  5278412380     F   33    50248      0
# 4  5776057280     M   33   146710      0
# -----------------------------------------------

# %% [markdown]
# ### Linear Kernel Classifier and Confusion matrix

# %%
# Training phase
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler


x = data.iloc[:, 2:4]   # We get the Age and Salaire values
y = data.iloc[:, 4]     # We get the value that we want to find out: Achat
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.25)

# Scaling phase
xSca = StandardScaler()
xTrain = xSca.fit_transform(xTrain)
xTest = xSca.transform(xTest)

# Initializing the classifier using SVC
# note that we use linear kernel
clf = SVC(kernel='linear', random_state=0).fit(xTrain, yTrain)

# Plot with Linear Kernel
xSet, ySet = xTrain, yTrain
X1, X2 = np.meshgrid(np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01),
                     np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01))
plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))
for i, j in enumerate(np.unique(ySet)):
    plt.scatter(xSet[ySet == j, 0], xSet[ySet == j, 1],
                c=ListedColormap(('blue', 'green'))(i), label=j)
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
plt.title('SVC (Linear Kernel) Classifier')
plt.xlabel('Age')
plt.ylabel('Salaire')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
import sklearn.metrics as metrics
import itertools 
# Confusion matrix for linear kernel
y_pred = clf.predict(xTest)

score = metrics.accuracy_score(yTest, y_pred)
print("Accuracy: %0.3f" % score)
cm = metrics.confusion_matrix(yTest, y_pred, labels=[0, 1])
plot_confusion_matrix(cm, classes=['False', 'True'])
# Out:
# Accuracy: 0.536
# Confusion matrix, without normalization

# %% [markdown]
# ### Poly Kernel Classifier and Confusion matrix

# %%
# Same moves, using poly kernel
clf = SVC(kernel='poly', random_state=0).fit(xTrain, yTrain)

#Plot with Poly kernel
xSet, ySet = xTrain, yTrain
X1, X2 = np.meshgrid(np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01),
                     np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01))
plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))
for i, j in enumerate(np.unique(ySet)):
    plt.scatter(xSet[ySet == j, 0], xSet[ySet == j, 1],
                c=ListedColormap(('blue', 'green'))(i), label=j)

plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
plt.title('SVC (Polynomial Kernel) Classifier')
plt.xlabel('Age')
plt.ylabel('Salaire')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
import sklearn.metrics as metrics
import itertools 
# Confusion matrix for Poly kernel

y_pred = clf.predict(xTest)

score = metrics.accuracy_score(yTest, y_pred)
print("Accuracy: %0.3f" % score)
cm = metrics.confusion_matrix(yTest, y_pred, labels=[0, 1])
plot_confusion_matrix(cm, classes=['False', 'True'])
# Out:
# Accuracy: 0.536
# Confusion matrix, without normalization

# %% [markdown]
# # 2.3 Results of SVM
#
# Network.csv :
#
# Linear kernel : 78/100 = 0.780
# Poly kernel : 83/100 = 0.830
#
# Using SVM on Network.csv results on pretty good results around 80% of success in the prediction. This could evolve to something more accurate with more datas provided for the training and testing. But we already see better results with poly kernel instead of linear as the hyperplane decision boundary between the classes of poly kernel is better in this case.
#
# People.csv :
#
# Linear kernel : 138/250 = 0.552
# Poly kernel : 132/250 = 0.528
#
# In this case the opinion is even stronger as the data is totally random. If a corollation exists, it is generated totally randomly.

# %% [markdown]
# # 3. KNN
#
# ## 3.1 Network.csv dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC           # Support Vector Classifier
from matplotlib.colors import ListedColormap

data = pd.read_csv('Network.csv')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier


# Training phase
x = data.iloc[:, 2:4]   # We get the Age and Salaire values
y = data.iloc[:, 4]     # We get the value that we want to find out: Achat
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.25)

# Scaling phase
xSca = StandardScaler()
xTrain = xSca.fit_transform(xTrain)
xTest = xSca.transform(xTest)


# Initializing the classifier using SVC
# note that we use linear kernel
clf = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2) # p = 1 is manhattan distance, p = 2 is Euclidean
clf.fit(xTrain, yTrain)


xSet, ySet = xTrain, yTrain
X1, X2 = np.meshgrid(np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01),
                     np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01))
plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))
for i, j in enumerate(np.unique(ySet)):
    plt.scatter(xSet[ySet == j, 0], xSet[ySet == j, 1],
                c=ListedColormap(('blue', 'green'))(i), label=j)

plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
plt.title('KNN Classifier')
plt.xlabel('Age')
plt.ylabel('Salaire')
plt.show()

y_pred = clf.predict(xTest)


score = metrics.accuracy_score(yTest, y_pred)
print("Accuracy: %0.3f" % score)

cm = confusion_matrix(yTest, y_pred)
plot_confusion_matrix(cm, classes=['False', 'True'])
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# Accuracy: 0.880
# Confusion matrix, without normalization

# %% [markdown]
# ## 3.2 People.csv dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC           # Support Vector Classifier
from matplotlib.colors import ListedColormap

data = pd.read_csv('People.csv')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier


# Training phase
x = data.iloc[:, 2:4]   # We get the Age and Salaire values
y = data.iloc[:, 4]     # We get the value that we want to find out: Achat
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.25)

# Scaling phase
xSca = StandardScaler()
xTrain = xSca.fit_transform(xTrain)
xTest = xSca.transform(xTest)


# Initializing the classifier using SVC
# note that we use linear kernel
clf = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2) # p = 1 is manhattan distance, p = 2 is Euclidean
clf.fit(xTrain, yTrain)


xSet, ySet = xTrain, yTrain
X1, X2 = np.meshgrid(np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01),
                     np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01))
plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))
for i, j in enumerate(np.unique(ySet)):
    plt.scatter(xSet[ySet == j, 0], xSet[ySet == j, 1],
                c=ListedColormap(('blue', 'green'))(i), label=j)

plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
plt.title('KNN Classifier')
plt.xlabel('Age')
plt.ylabel('Salaire')
plt.show()

y_pred = clf.predict(xTest)


score = metrics.accuracy_score(yTest, y_pred)
print("Accuracy: %0.3f" % score)

cm = confusion_matrix(yTest, y_pred)
plot_confusion_matrix(cm, classes=['False', 'True'])
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# Accuracy: 0.524
# Confusion matrix, without normalization

# %% [markdown]
# ## 3.3 Results of KNN
#
# Network.csv :
#
# Accuracy = 88/100 = 0.880
#
# People.csv :
#
# Accuracy: 114/250 = 0.456
#
# KNN has even better results than SVM for Network.csv but performs worse in  the case of People.csv.

# %% [markdown]
# # 3. Decision tree
#
# ## 3.1 Network.csv dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC           # Support Vector Classifier
from matplotlib.colors import ListedColormap

data = pd.read_csv('Network.csv')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier


# Training phase
x = data.iloc[:, 2:4]   # We get the Age and Salaire values
y = data.iloc[:, 4]     # We get the value that we want to find out: Achat
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.25)

# Scaling phase
xSca = StandardScaler()
xTrain = xSca.fit_transform(xTrain)
xTest = xSca.transform(xTest)


# Initializing the classifier using SVC
# note that we use linear kernel
clf = DecisionTreeClassifier(criterion='entropy', random_state=0)
clf.fit(xTrain, yTrain)


xSet, ySet = xTrain, yTrain
X1, X2 = np.meshgrid(np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01),
                     np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01))
plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))
for i, j in enumerate(np.unique(ySet)):
    plt.scatter(xSet[ySet == j, 0], xSet[ySet == j, 1],
                c=ListedColormap(('blue', 'green'))(i), label=j)

plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
plt.title('Decision Tree Classifier')
plt.xlabel('Age')
plt.ylabel('Salaire')
plt.show()

y_pred = clf.predict(xTest)


score = metrics.accuracy_score(yTest, y_pred)
print("Accuracy: %0.3f" % score)

cm = confusion_matrix(yTest, y_pred)
plot_confusion_matrix(cm, classes=['False', 'True'])
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# Accuracy: 0.870
# Confusion matrix, without normalization

# %% [markdown]
# ## 3.2 People.csv dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC           # Support Vector Classifier
from matplotlib.colors import ListedColormap

data = pd.read_csv('People.csv')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier


# Training phase
x = data.iloc[:, 2:4]   # We get the Age and Salaire values
y = data.iloc[:, 4]     # We get the value that we want to find out: Achat
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.25)

# Scaling phase
xSca = StandardScaler()
xTrain = xSca.fit_transform(xTrain)
xTest = xSca.transform(xTest)


# Initializing the classifier using SVC
# note that we use linear kernel
clf = DecisionTreeClassifier(criterion='entropy', random_state=0)
clf.fit(xTrain, yTrain)


xSet, ySet = xTrain, yTrain
X1, X2 = np.meshgrid(np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01),
                     np.arange(start=xSet[:, 0].min() - 1, stop=xSet[:, 0].max() + 1, step=0.01))
plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.75, cmap=ListedColormap(('red', 'green')))
for i, j in enumerate(np.unique(ySet)):
    plt.scatter(xSet[ySet == j, 0], xSet[ySet == j, 1],
                c=ListedColormap(('blue', 'green'))(i), label=j)

plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
plt.title('Decision Tree Classifier')
plt.xlabel('Age')
plt.ylabel('Salaire')
plt.show()

y_pred = clf.predict(xTest)


score = metrics.accuracy_score(yTest, y_pred)
print("Accuracy: %0.3f" % score)

cm = confusion_matrix(yTest, y_pred)
plot_confusion_matrix(cm, classes=['False', 'True'])
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# Accuracy: 0.500
# Confusion matrix, without normalization

# %% [markdown]
# ## 3.3 Results for Decision Tree
#
# Network.csv :
# Accuracy : 85/100 = 0.850
#
# People.csv :
# Accuracy = 120/250 = 0.520
#
# Performing better than SVM but less well than KNN. As expected, People.csv stays around 50% as there are only 2 classes.

# %% [markdown]
# # 4. Logistic Regression

# %% [markdown]
# ## 4.1 Network.csv dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

data = pd.read_csv('Network.csv')

# %%
from sklearn.linear_model import LogisticRegression

x = data.iloc[:, 2:4]   # We get the Age and Salaire values
y = data.iloc[:, 4]     # We get the value that we want to find out: Achat

#Using train_test_split method to splitting the data into training part and testing part for Ml
#Here test_size = 0.2 means Ml model will take only 80% of the data to train and 20% data to test
#Here random_state means it will not change the trainning and testing part after running this many times
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state = 1)

# Scaling phase
xSca = StandardScaler()
xTrain = xSca.fit_transform(xTrain)
xTest = xSca.transform(xTest)

log_reg = LogisticRegression() #having the logisticregreesion as variable

log_reg.fit(xTrain , yTrain) #fitting the trainning data to use the Ml-LogisticRegression


y_pred = log_reg.predict(xTest) #Predicting the testing data

#Having a confusion matrix to know connection between actual value and Predicting value
score = metrics.accuracy_score(yTest, y_pred)
print("Accuracy: %0.3f" % score)

cm = confusion_matrix(yTest, y_pred)
plot_confusion_matrix(cm, classes=['False', 'True'])

#Getting the score(r-squared) value..if the score is close to 1 which means our prediction is good

print("Coef : ", log_reg.coef_)
print("Intercept : ", log_reg.intercept_)
print("Score (r-squared) : ", log_reg.score(xTest,yTest))
# Out:
# Accuracy: 0.838
# Confusion matrix, without normalization
#
# Coef :  [[2.33967724 1.33090165]]
# Intercept :  [-1.19031563]
# Score (r-squared) :  0.8375

# %% [markdown]
# ## 4.2 People.csv dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

data = pd.read_csv('People.csv')

# %%
from sklearn.linear_model import LogisticRegression

x = data.iloc[:, 2:4]   # We get the Age and Salaire values
y = data.iloc[:, 4]     # We get the value that we want to find out: Achat

xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state = 1)

# Scaling phase
xSca = StandardScaler()
xTrain = xSca.fit_transform(xTrain)
xTest = xSca.transform(xTest)

log_reg = LogisticRegression() 

log_reg.fit(xTrain , yTrain) 


y_pred = log_reg.predict(xTest) 


score = metrics.accuracy_score(yTest, y_pred)
print("Accuracy: %0.3f" % score)

cm = confusion_matrix(yTest, y_pred)
plot_confusion_matrix(cm, classes=['False', 'True'])


print("Coef : ", log_reg.coef_)
print("Intercept : ", log_reg.intercept_)
print("Score (r-squared) : ", log_reg.score(xTest,yTest))
# Out:
# Accuracy: 0.550
# Confusion matrix, without normalization
#
# Coef :  [[ 0.0018656  -0.00934666]]
# Intercept :  [-0.06502438]
# Score (r-squared) :  0.55

# %% [markdown]
# ## 4.3 Results of Logistic Regression
#
# Network.csv :
# Accuracy : 67/80 = 0.8375
#
# People.csv :
# Accuracy = 110/200 = 0.55

# %% [markdown]
# # 5. Linear regression
#
# Note: Unfortunately, we didn't find any way to make the next ones work with our Network.csv & People.csv.
# So we created a second table dataset with a link on the salary and the year of experience.

# %% [markdown]
# ## 5.1 Salary.csv dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('Salary.csv')

# %%
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression

x = data.iloc[:, :-1].values  
y = data.iloc[:, 1].values    
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.2, random_state = 0)

regressor = LinearRegression()
regressor.fit(xTrain, yTrain)

LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
y_pred = regressor.predict(xTest)

print("Coef : ", log_reg.coef_)
print("Intercept : ", log_reg.intercept_)
print("Score (r-squared) : ", regressor.score(xTest,yTest))

plt.scatter(xTrain, yTrain, color = 'red')
plt.plot(xTrain, regressor.predict(xTrain), color = 'blue')
plt.title('Training set')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()


plt.scatter(xTest, yTest, color = 'red')
plt.plot(xTrain, regressor.predict(xTrain), color = 'blue')
plt.title('Test set')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
# Out:
# Coef :  [[ 0.0018656  -0.00934666]]
# Intercept :  [-0.06502438]
# Score (r-squared) :  0.988169515729126

# %% [markdown]
# ## 5.2 Results of Linear Regression
#
# The results are globally very satisfying as the line above shows our algorithm is correct. For every one unit of change in Years of Experience, the change in the Salary should be about 0.98%.

# %% [markdown]
# # 6. Support Vector Regression
#
# ## 6.1 Salary.csv dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('Salary.csv')

# %%
from sklearn.svm import SVR

x = data.iloc[:, :-1]   
y = data.iloc[:, 1]     
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.2, random_state = 0)

regressor = SVR(kernel='rbf').fit(x, y)



print("Score : ", regressor.score(xTest,yTest))

y_pred = regressor.predict(xTest)

print("Coef : ", log_reg.coef_)
print("Intercept : ", log_reg.intercept_)
print("Score (r-squared) : ", regressor.score(xTest,yTest))

plt.scatter(xTrain, yTrain, color = 'red')
plt.plot(xTrain, regressor.predict(xTrain), color = 'blue')
plt.title('Training set')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()


plt.scatter(xTest, yTest, color = 'red')
plt.plot(xTrain, regressor.predict(xTrain), color = 'blue')
plt.title('Test set')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
# Out:
# Score :  -0.3405815715683172
# Coef :  [[ 0.0018656  -0.00934666]]
# Intercept :  [-0.06502438]
# Score (r-squared) :  -0.3405815715683172

# %% [markdown]
# ## 6.2 Results for Support Vector Regression
#
# In this case, we don't understand the behaviour and tried multiple approach to find something appropriated but failed. For academical purposes, we still wanted to share this part of the work.

# %% [markdown]
# # 7. Conclusion
#
# To have a summarized view, here is a table with the best performing algorithm to the least performing. We will only fetch the results for Network.csv and another ranking for Salary.csv. What we observe after multiple runs is that the average of scoring is around 80%. KNN and Poly kernel as performing slightly better up to 90% in some runs. The values in this notebook may differ from one execution to another as no seed was used.
# As conclusion, we had the opportunity in this task to put in practice some theoretical approaches seen in diverse IA & Machine learning courses. We also compared our results and found the explanation behind the behaviour of our models and how our algorithms interacts and performs with them.
